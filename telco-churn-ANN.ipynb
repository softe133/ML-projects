# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
churn means "leaving the company". If the customer has left the company i.e churn = yes, if not leaving churn = No

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2497  5702-SKUOB  Female              0     Yes         No       4
# 4088  1196-AMORA    Male              0      No         No       7
# 4410  0848-ZGQIJ  Female              0     Yes         No      16
# 2044  2550-QHZGP    Male              0      No         No       7
# 4497  0575-CUQOV    Male              1     Yes         No      60
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 2497          Yes            No              No  No internet service
# 4088          Yes           Yes     Fiber optic                   No
# 4410          Yes            No     Fiber optic                   No
# 2044          Yes            No              No  No internet service
# 4497          Yes            No     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 2497  No internet service  No internet service  No internet service
# 4088                   No                   No                   No
# 4410                  Yes                   No                   No
# 2044  No internet service  No internet service  No internet service
# 4497                  Yes                  Yes                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 2497  No internet service  No internet service  Month-to-month
# 4088                   No                   No  Month-to-month
# 4410                  Yes                  Yes  Month-to-month
# 2044  No internet service  No internet service        One year
# 4497                  Yes                  Yes        One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 2497               No               Mailed check           19.60        93.45
# 4088               No           Electronic check           73.60          520
# 4410              Yes  Bank transfer (automatic)           94.65      1461.15
# 2044               No               Mailed check           19.50        128.6
# 4497              Yes           Electronic check           97.95         5867
#
#      Churn
# 2497    No
# 4088   Yes
# 4410    No
# 2044    No
# 4497    No

# %%
#Checking for datatypes
#Wesee that Total charges is an object. We need to change that to float
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ", 0).astype('float64')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
# data visuliazation
tenure_churn_no = df[df.Churn=='No'].tenure
tenure_churn_yes = df[df.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualization")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

#In this graph, we have the number of customers who will be leaving and not leaving the company, and we have the tenure of months that they have been apart of the company till now.

# %%
ax = sns.catplot(y="Churn", kind="count", data=df, height=2.6, aspect=2.5, orient='h')

# %%
def kdeplot(feature):
    plt.figure(figsize=(9, 4))
    plt.title("KDE for {}".format(feature))
    ax0 = sns.kdeplot(df[df['Churn'] == 'No'][feature].dropna(), color= 'navy', label= 'Churn: No')
    ax1 = sns.kdeplot(df[df['Churn'] == 'Yes'][feature].dropna(), color= 'orange', label= 'Churn: Yes')
kdeplot('tenure')
kdeplot('MonthlyCharges')
kdeplot('TotalCharges')

# %%
def barplot_percentages(feature, orient='v', axis_name="percentage of customers"):
    ratios = pd.DataFrame()
    g = df.groupby(feature)["Churn"].value_counts().to_frame()
    g = g.rename({"Churn": axis_name}, axis=1).reset_index()
    g[axis_name] = g[axis_name]/len(df)
    if orient == 'v':
        ax = sns.barplot(x=feature, y= axis_name, hue='Churn', data=g, orient=orient)
        ax.set_yticklabels(['{:,.0%}'.format(y) for y in ax.get_yticks()])
    else:
        ax = sns.barplot(x= axis_name, y=feature, hue='Churn', data=g, orient=orient)
        ax.set_xticklabels(['{:,.0%}'.format(x) for x in ax.get_xticks()])
    ax.plot()
barplot_percentages("SeniorCitizen")
# Out:
# C:\Users\ALFURQ~1\AppData\Local\Temp/ipykernel_9972/934766672.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(y) for y in ax.get_yticks()])

# %%
df['churn_rate'] = df['Churn'].replace("No", 0).replace("Yes", 1)
g = sns.FacetGrid(df, col="SeniorCitizen", height=4, aspect=.9)
ax = g.map(sns.barplot, "gender", "churn_rate", palette = "Blues_d", order= ['Female', 'Male'])

# %%
plt.figure(figsize=(9, 4.5))
barplot_percentages("MultipleLines", orient='h')
# Out:
# C:\Users\ALFURQ~1\AppData\Local\Temp/ipykernel_9972/934766672.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['{:,.0%}'.format(x) for x in ax.get_xticks()])

# %%
plt.figure(figsize=(9, 4.5))
barplot_percentages("InternetService", orient="h")
# Out:
# C:\Users\ALFURQ~1\AppData\Local\Temp/ipykernel_9972/934766672.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['{:,.0%}'.format(x) for x in ax.get_xticks()])

# %%
#There are six additional services for customers with internet:
cols = ["OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies"]
df1 = pd.melt(df[df["InternetService"] != "No"][cols]).rename({'value': 'Has service'}, axis=1)
plt.figure(figsize=(10, 4.5))
ax = sns.countplot(data=df1, x='variable', hue='Has service')
ax.set(xlabel='Additional service', ylabel='Num of customers')
plt.show()

# %%
plt.figure(figsize=(10, 4.5))
df1 = df[(df.InternetService != "No") & (df.Churn == "Yes")]
df1 = pd.melt(df1[cols]).rename({'value': 'Has service'}, axis=1)
ax = sns.countplot(data=df1, x='variable', hue='Has service', hue_order=['No', 'Yes'])
ax.set(xlabel='Additional service', ylabel='Num of churns')
plt.show()

# %%
g = sns.FacetGrid(df, col="PaperlessBilling", height=4, aspect=.9)
ax = g.map(sns.barplot, "Contract", "churn_rate", palette = "Blues_d", order= ['Month-to-month', 'One year', 'Two year'])

# %%
plt.figure(figsize=(9, 4.5))
barplot_percentages("PaymentMethod", orient='h')
# Out:
# C:\Users\ALFURQ~1\AppData\Local\Temp/ipykernel_9972/934766672.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['{:,.0%}'.format(x) for x in ax.get_xticks()])

# %%
plt.figure(figsize=(12, 6))
df.drop(['customerID', 'churn_rate'],
        axis=1, inplace=True)
corr = df.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=.2, cmap="YlGnBu")

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
#Let's print unique values in object columns to see data values
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
#Some of the columns have no internet service or no phone service, that can be replaced with a simple No
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               No             DSL             No          Yes
# 1               No             DSL            Yes           No
# 2               No             DSL            Yes          Yes
# 3               No             DSL            Yes           No
# 4               No     Fiber optic             No           No
# ...            ...             ...            ...          ...
# 7038           Yes             DSL            Yes           No
# 7039           Yes     Fiber optic             No          Yes
# 7040            No             DSL            Yes           No
# 7041           Yes     Fiber optic             No           No
# 7042            No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 2                 Yes               Mailed check           53.85
# 3                  No  Bank transfer (automatic)           42.30
# 4                 Yes           Electronic check           70.70
# ...               ...                        ...             ...
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7041              Yes               Mailed check           74.40
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 2           108.15   Yes
# 3          1840.75    No
# 4           151.65   Yes
# ...            ...   ...
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7041        306.60   Yes
# 7042       6844.50    No
#
# [7043 rows x 20 columns]

# %%
#Here, converting Yes= 1, No =0

yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1 = pd.get_dummies(data=df, columns=['InternetService','Contract','PaymentMethod'])
df1.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df1.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3833       0              0        0           0      12             1
# 5117       1              0        0           0      66             0
# 4635       1              0        1           1      40             1
# 2123       0              0        0           0      31             1
# 6849       0              0        1           1      30             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3833              1               0             0                 1
# 5117              0               1             0                 1
# 4635              0               0             0                 0
# 2123              1               0             1                 0
# 6849              1               0             1                 0
#
#       TechSupport  StreamingTV  StreamingMovies  PaperlessBilling  \
# 3833            0            1                1                 0
# 5117            1            1                1                 1
# 4635            0            0                0                 0
# 2123            0            0                0                 1
# 6849            1            0                0                 1
#
#       MonthlyCharges  TotalCharges  Churn  InternetService_DSL  \
# 3833           74.75        827.05      0                    1
# 5117           61.35       4193.40      0                    1
# 4635           20.15        777.35      0                    0
# 2123           80.45       2429.10      0                    0
# 6849           83.55       2570.20      0                    0
#
#       InternetService_Fiber optic  InternetService_No  \
# 3833                            0                   0
# 5117                            0                   0
# 4635                            0                   1
# 2123                            1                   0
# 6849                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 3833                        1                  0                  0
# 5117                        0                  0                  1
# 4635                        0                  0                  1
# 2123                        1                  0                  0
# 6849                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 3833                                        1
# 5117                                        1
# 4635                                        1
# 2123                                        0
# 6849                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 3833                                      0                               0
# 5117                                      0                               0
# 4635                                      0                               0
# 2123                                      0                               1
# 6849                                      0                               0
#
#       PaymentMethod_Mailed check
# 3833                           0
# 5117                           0
# 4635                           0
# 2123                           0
# 6849                           0

# %%
df1.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1[cols_to_scale] = scaler.fit_transform(df1[cols_to_scale])

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.01388889 0.47222222 0.02777778 0.625      0.11111111 0.30555556
#  0.13888889 0.38888889 0.86111111 0.18055556 0.22222222 0.80555556
#  0.68055556 0.34722222 0.95833333 0.72222222 0.98611111 0.29166667
#  0.16666667 0.41666667 0.65277778 1.         0.23611111 0.375
#  0.06944444 0.63888889 0.15277778 0.97222222 0.875      0.59722222
#  0.20833333 0.83333333 0.25       0.91666667 0.125      0.04166667
#  0.43055556 0.69444444 0.88888889 0.77777778 0.09722222 0.58333333
#  0.48611111 0.66666667 0.40277778 0.90277778 0.52777778 0.94444444
#  0.44444444 0.76388889 0.51388889 0.5        0.56944444 0.08333333
#  0.05555556 0.45833333 0.93055556 0.31944444 0.79166667 0.84722222
#  0.19444444 0.27777778 0.73611111 0.55555556 0.81944444 0.33333333
#  0.61111111 0.26388889 0.75       0.70833333 0.36111111 0.
#  0.54166667]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.00343704 0.21756402 0.01245279 ... 0.03989153 0.03530306 0.78810105]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df1.drop('Churn',axis='columns')
y = df1['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5634, 26)

# %%
X_test.shape
# Out:
# (1409, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5860       1              0        0           0  0.027778             1
# 2458       0              1        1           0  0.694444             1
# 5879       0              0        1           0  0.458333             1
# 4708       1              0        1           1  0.777778             1
# 1293       0              0        1           1  0.930556             1
# 2242       0              0        1           1  0.611111             1
# 1444       0              0        0           1  0.569444             1
# 3269       0              0        0           0  0.902778             1
# 101        1              0        1           1  0.013889             1
# 4191       1              0        1           0  0.875000             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 5860              0               0             0                 0
# 2458              1               1             0                 1
# 5879              0               1             1                 0
# 4708              0               1             1                 1
# 1293              1               0             1                 1
# 2242              1               0             0                 0
# 1444              0               1             1                 1
# 3269              1               0             0                 0
# 101               0               0             0                 0
# 4191              1               0             1                 1
#
#       TechSupport  StreamingTV  StreamingMovies  PaperlessBilling  \
# 5860            0            0                0                 0
# 2458            0            1                1                 1
# 5879            1            0                0                 1
# 4708            0            0                0                 1
# 1293            1            1                1                 1
# 2242            0            0                0                 0
# 1444            1            1                1                 1
# 3269            0            0                0                 0
# 101             0            0                0                 0
# 4191            1            1                1                 1
#
#       MonthlyCharges  TotalCharges  InternetService_DSL  \
# 5860        0.514925      0.017623                    0
# 2458        0.863682      0.594521                    0
# 5879        0.425871      0.232406                    1
# 4708        0.428358      0.385363                    1
# 1293        0.924876      0.867124                    0
# 2242        0.065672      0.116710                    0
# 1444        0.924378      0.518970                    0
# 3269        0.065174      0.184339                    0
# 101         0.011940      0.002240                    0
# 4191        0.900498      0.791233                    0
#
#       InternetService_Fiber optic  InternetService_No  \
# 5860                            1                   0
# 2458                            1                   0
# 5879                            0                   0
# 4708                            0                   0
# 1293                            1                   0
# 2242                            0                   1
# 1444                            1                   0
# 3269                            0                   1
# 101                             0                   1
# 4191                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5860                        1                  0                  0
# 2458                        0                  0                  1
# 5879                        0                  0                  1
# 4708                        0                  0                  1
# 1293                        0                  0                  1
# 2242                        0                  1                  0
# 1444                        0                  0                  1
# 3269                        0                  1                  0
# 101                         1                  0                  0
# 4191                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5860                                        1
# 2458                                        0
# 5879                                        0
# 4708                                        0
# 1293                                        1
# 2242                                        0
# 1444                                        0
# 3269                                        0
# 101                                         0
# 4191                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5860                                      0                               0
# 2458                                      1                               0
# 5879                                      0                               0
# 4708                                      1                               0
# 1293                                      0                               0
# 2242                                      0                               1
# 1444                                      0                               1
# 3269                                      1                               0
# 101                                       0                               1
# 4191                                      0                               1
#
#       PaymentMethod_Mailed check
# 5860                           0
# 2458                           0
# 5879                           1
# 4708                           0
# 1293                           0
# 2242                           0
# 1444                           0
# 3269                           0
# 101                            0
# 4191                           0

# %%
len(X_train.columns)
# Out:
# 26

# %%
model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 177/177 [==============================] - 3s 4ms/step - loss: 0.4979 - accuracy: 0.7515
# Epoch 2/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4258 - accuracy: 0.7998
# Epoch 3/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4188 - accuracy: 0.8014
# Epoch 4/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4151 - accuracy: 0.8076
# Epoch 5/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4132 - accuracy: 0.8044
# Epoch 6/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4120 - accuracy: 0.8076
# Epoch 7/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4100 - accuracy: 0.8081
# Epoch 8/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4093 - accuracy: 0.8092
# Epoch 9/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4072 - accuracy: 0.8104
# Epoch 10/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4070 - accuracy: 0.8111
# Epoch 11/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4067 - accuracy: 0.8103
# Epoch 12/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4049 - accuracy: 0.8111
# Epoch 13/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4044 - accuracy: 0.8122
# Epoch 14/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4034 - accuracy: 0.8117
# Epoch 15/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4036 - accuracy: 0.8126
# Epoch 16/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8138
# Epoch 17/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4009 - accuracy: 0.8120
# Epoch 18/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4000 - accuracy: 0.8135
# Epoch 19/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4002 - accuracy: 0.8163
# Epoch 20/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3983 - accuracy: 0.8147
# Epoch 21/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3979 - accuracy: 0.8161
# Epoch 22/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3977 - accuracy: 0.8163
# Epoch 23/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3970 - accuracy: 0.8129
# Epoch 24/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3955 - accuracy: 0.8166
# Epoch 25/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3950 - accuracy: 0.8161
# Epoch 26/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3946 - accuracy: 0.8161
# Epoch 27/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3935 - accuracy: 0.8216
# Epoch 28/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8181
# Epoch 29/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3927 - accuracy: 0.8184
# Epoch 30/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3908 - accuracy: 0.8179
# Epoch 31/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3898 - accuracy: 0.8193
# Epoch 32/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3907 - accuracy: 0.8182
# Epoch 33/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3890 - accuracy: 0.8163
# Epoch 34/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3880 - accuracy: 0.8223
# Epoch 35/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3867 - accuracy: 0.8188
# Epoch 36/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3864 - accuracy: 0.8195
# Epoch 37/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3861 - accuracy: 0.8179
# Epoch 38/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.8232
# Epoch 39/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8229
# Epoch 40/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3848 - accuracy: 0.8230
# Epoch 41/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3831 - accuracy: 0.8193
# Epoch 42/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3833 - accuracy: 0.8198
# Epoch 43/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3816 - accuracy: 0.8225
# Epoch 44/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8216
# Epoch 45/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3804 - accuracy: 0.8223
# Epoch 46/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8227
# Epoch 47/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3809 - accuracy: 0.8213
# Epoch 48/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3799 - accuracy: 0.8214
# Epoch 49/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3801 - accuracy: 0.8243
# Epoch 50/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3781 - accuracy: 0.8230
# Epoch 51/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3771 - accuracy: 0.8250
# Epoch 52/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3775 - accuracy: 0.8230
# Epoch 53/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8239
# Epoch 54/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.8237
# Epoch 55/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.8206
# Epoch 56/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3757 - accuracy: 0.8206
# Epoch 57/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3734 - accuracy: 0.8246
# Epoch 58/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3730 - accuracy: 0.8287
# Epoch 59/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3737 - accuracy: 0.8261
# Epoch 60/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3727 - accuracy: 0.8246
# Epoch 61/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3711 - accuracy: 0.8259
# Epoch 62/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3720 - accuracy: 0.8257
# Epoch 63/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3709 - accuracy: 0.8271
# Epoch 64/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3714 - accuracy: 0.8255
# Epoch 65/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3688 - accuracy: 0.8236
# Epoch 66/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3698 - accuracy: 0.8268
# Epoch 67/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3689 - accuracy: 0.8257
# Epoch 68/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3688 - accuracy: 0.8296
# Epoch 69/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3676 - accuracy: 0.8277
# Epoch 70/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3682 - accuracy: 0.8271
# Epoch 71/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3661 - accuracy: 0.8294
# Epoch 72/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3671 - accuracy: 0.8280
# Epoch 73/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3667 - accuracy: 0.8264
# Epoch 74/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3651 - accuracy: 0.8301
# Epoch 75/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3665 - accuracy: 0.8284
# Epoch 76/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3649 - accuracy: 0.8287
# Epoch 77/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3641 - accuracy: 0.8321
# Epoch 78/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3639 - accuracy: 0.8277
# Epoch 79/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8321
# Epoch 80/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3639 - accuracy: 0.8277
# Epoch 81/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3629 - accuracy: 0.8300
# Epoch 82/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3626 - accuracy: 0.8300
# Epoch 83/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3617 - accuracy: 0.8307
# Epoch 84/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3626 - accuracy: 0.8303
# Epoch 85/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3623 - accuracy: 0.8305
# Epoch 86/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3611 - accuracy: 0.8298
# Epoch 87/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3601 - accuracy: 0.8275
# Epoch 88/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3604 - accuracy: 0.8282
# Epoch 89/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3599 - accuracy: 0.8303
# Epoch 90/100
# 177/177 [==============================] - 1s 5ms/step - loss: 0.3607 - accuracy: 0.8307
# Epoch 91/100
# 177/177 [==============================] - 1s 5ms/step - loss: 0.3586 - accuracy: 0.8310
# Epoch 92/100
# 177/177 [==============================] - 1s 4ms/step - loss: 0.3582 - accuracy: 0.8310
# Epoch 93/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3591 - accuracy: 0.8303
# Epoch 94/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3583 - accuracy: 0.8296
# Epoch 95/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3574 - accuracy: 0.8287
# Epoch 96/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3561 - accuracy: 0.8310
# Epoch 97/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3560 - accuracy: 0.8335
# Epoch 98/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3557 - accuracy: 0.8319
# Epoch 99/100
# 177/177 [==============================] - 0s 3ms/step - loss: 0.3557 - accuracy: 0.8333
# Epoch 100/100
# 177/177 [==============================] - 1s 3ms/step - loss: 0.3541 - accuracy: 0.8305

# %%
model.evaluate(X_test, y_test)
# Out:
# 45/45 [==============================] - 1s 3ms/step - loss: 0.4745 - accuracy: 0.7864
# [0.474540114402771, 0.7863733172416687]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.21306768],
#        [0.6779911 ],
#        [0.311028  ],
#        [0.8438282 ],
#        [0.06396234]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 1, 0, 0]

# %%
y_test[:10]
# Out:
# 4213    1
# 5035    0
# 3713    1
# 1720    0
# 234     0
# 4558    1
# 40      0
# 3455    1
# 5944    1
# 1089    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85      1023
#            1       0.62      0.58      0.60       386
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.72      0.73      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1409,)

# %%
round((862+229)/(862+229+137+179),2)
# Out:
# 0.78

# %%
round(862/(862+179),2)
# Out:
# 0.83

# %%
round(229/(229+137),2)
# Out:
# 0.63

# %%
round(862/(862+137),2)
# Out:
# 0.86

# %%
round(229/(229+179),2)
# Out:
# 0.56
